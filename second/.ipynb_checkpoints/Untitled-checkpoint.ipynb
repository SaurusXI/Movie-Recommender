# %% [markdown]
# # Content based filtering

# %%
import dask.dataframe as dd
import dask.array as da
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from dask_ml.metrics.pairwise import linear_kernel

# %%
links = dd.read_csv('../links.csv')
top_charts = pd.read_csv('../FIRST-top_charts.csv')
metadata = pd.read_csv('../movies_metadata.csv')
metadata.head()
# Out:
# /usr/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3050: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# ...

# %%
metadata['tagline'] = metadata['tagline'].fillna(' ')
metadata['overview'] = metadata['overview'].fillna(' ')
metadata['description'] = metadata['overview'].apply(lambda x: x.lower()) + ' ' + metadata['tagline'].apply(lambda x: x.lower())
metadata.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
vectorizer = TfidfVectorizer(analyzer = 'word', stop_words = 'english')
description_matrix = vectorizer.fit_transform(metadata['description'])
description_matrix.shape
# Out:
# (45466, 77132)

# %%
similarity_matrix = da.rechunk(linear_kernel(description_matrix, description_matrix), chunks = (100, 1))
indices = pd.Series(metadata.index, index = metadata['title'])
titles = pd.Series(metadata['title'], index = metadata.index)

# %%
def get_recommendations(movie_name):
    index = indices[movie_name]
    scores = list(enumerate(similarity_matrix[index]))
    scores = sorted(scores, key = lambda x: x[1], reverse = True)[1:51]
    movie_indices = [i[0] for i in scores]
    recommendations = [titles[i] for i in movie_indices]
    return titles

# %%
similarity_matrix
# Out:
# dask.array<sum-aggregate, shape=(45466, 45466), dtype=float64, chunksize=(45466, 45466), chunktype=numpy.ndarray>

# %%
similarity_matrix[0]
# Out:
# dask.array<getitem, shape=(45466,), dtype=float64, chunksize=(45466,), chunktype=numpy.ndarray>

# %%
similarity_matrix[0].compute()
# Out:
# -------------------------------------------------------------------
# IndexError                        Traceback (most recent call last)
# <ipython-input-48-bdbc60beb0f9> in <module>
# ----> 1 similarity_matrix[0].compute()
#
# ~/.local/lib/python3.8/site-packages/dask/base.py in compute(self, **kwargs)
#     163         dask.base.compute
#     164         """
# --> 165         (result,) = compute(self, traverse=False, **kwargs)
#     166         return result
#     167
#
# ~/.local/lib/python3.8/site-packages/dask/base.py in compute(*args, **kwargs)
#     434     keys = [x.__dask_keys__() for x in collections]
#     435     postcomputes = [x.__dask_postcompute__() for x in collections]
# --> 436     results = schedule(dsk, keys, **kwargs)
#     437     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     438
#
# ~/.local/lib/python3.8/site-packages/dask/threaded.py in get(dsk, result, cache, num_workers, pool, **kwargs)
# ...
